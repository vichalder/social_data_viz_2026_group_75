# %% [markdown]
# # Week 5

# %%
import pandas as pd
import numpy as np
import plotly as ply
import matplotlib as plt
import folium as fl
from urllib.request import urlopen
import json

# %%
data = pd.read_csv(r"G:\My Drive\Skole\DTU\10. semester\02806 Social_data_viz\social_data_viz_2026_group_75\Data\2003_2026.csv")

# %%
data['Incident Datetime'] = pd.to_datetime(data['Incident Datetime'])

# %%
with urlopen('https://raw.githubusercontent.com/plotly/datasets/master/geojson-counties-fips.json') as response:
    counties = json.load(response)

counties["features"][0]
# Out:
# {'type': 'Feature',
#  'properties': {'GEO_ID': '0500000US01001',
#   'STATE': '01',
#   'COUNTY': '001',
#   'NAME': 'Autauga',
#   'LSAD': 'County',
#   'CENSUSAREA': 594.436},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[-86.496774, 32.344437],
#     [-86.717897, 32.402814],
#     [-86.814912, 32.340803],
#     [-86.890581, 32.502974],
#     [-86.917595, 32.664169],
#     [-86.71339, 32.661732],
#     [-86.714219, 32.705694],
#     [-86.413116, 32.707386],
#     [-86.411172, 32.409937],
#     [-86.496774, 32.344437]]]},
#  'id': '01001'}

# %% [markdown]
# ## Part 1

# %%
randomdata = {
    'CENTRAL': 0.4821,
    'SOUTHERN': 0.9153,
    'BAYVIEW': 0.3674,
    'MISSION': 0.7542,
    'PARK': 0.6285,
    'RICHMOND': 0.2147,
    'INGLESIDE': 0.05391,
    'TARAVAL': 0.007846,
    'NORTHERN': 0.4938,
    'TENDERLOIN': 0.08127
}

# %%
random_frame = ['District', 'Value']
random_frame['District']
